# %%
import pickle
import warnings
warnings.filterwarnings('ignore')
import time
import os
import numpy as np
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.mpl_style = 'default'

from sklearn.ensemble import RandomForestRegressor, BaggingRegressor, ExtraTreesRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn.linear_model import Ridge, Lasso,ElasticNet,LinearRegression
from sklearn.neural_network import MLPRegressor
from sklearn import svm
from sklearn.metrics import mean_squared_error, make_scorer,mean_absolute_error

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
PROCESSINGTEXT_DIR =  '../home_depot/data'
df_train = pd.read_csv(PROCESSINGTEXT_DIR + '/merged_train_df.csv', encoding="ISO-8859-1")
X_train = df_train.drop(['id','relevance'],axis=1)

# %%
mingw_path = 'C:\\Program Files\\mingw-w64\\x86_64-6.3.0-posix-seh-rt_v5-rev1\\mingw64\\bin'
os.environ['PATH'] = mingw_path + ';' + os.environ['PATH']
import xgboost as xgb

# %%
clf_lr = pickle.load(open('clf_lr.sav','rb'))
clf_lasso = pickle.load(open('clf_lasso.sav','rb'))
clf_ridge = pickle.load(open('clf_ridge.sav','rb'))
clf_EN = pickle.load(open('clf_EN.sav','rb'))

# %%
names =[str(x) for x in list(X_train.columns)]

# %%
a = pd.DataFrame(clf.get_fscore(), index=['xgb']).transpose()
e = a["xgb"].reset_index()
e["index"]=(e["index"].map(lambda x:int(x.split("f")[1])))
e=e.sort(["index"], ascending=True)

# %%
clf_AB = pickle.load(open('clf_AB.sav','rb'))
clf_rf = pickle.load(open('clf_rf.sav','rb'))
clf_ET = pickle.load(open('clf_ET.sav','rb'))
clf = pickle.load(open('clf.sav','rb'))
clf_xgb = pickle.load(open('clf_xgb.sav','rb'))

# %%
importance = pd.DataFrame({'Feature':names,'Ada':clf_AB.feature_importances_,'xgb':e.xgb,'RF':clf_rf.feature_importances_,'ET':clf_ET.feature_importances_,
              'xgbR':clf_xgb.feature_importances_,'lr':clf_lr.coef_,'lasso':clf_lasso.coef_,'ridge':clf_ridge.coef_,'EN':clf_EN.coef_})

# %%
importance.to_csv('importance.csv',index=False)

# %%
importance
# Out:
#          Ada            EN        ET                              Feature  \
# 0   0.000481 -3.020438e-07  0.023449                       search_term_id
# 1   0.067399 -1.931409e-06  0.047174                          product_uid
# 12  0.024893  8.043783e-01  0.012521                  is_query_misspelled
# 23  0.020371 -4.962416e-02  0.020154                         len_of_query
# 34  0.000000 -7.903848e-03  0.021249                         len_of_title
# 43  0.000000  2.608566e-03  0.003664                 query_brand_matching
# 44  0.000000  7.018834e-03  0.003466         query_brandintitile_matching
# 45  0.000000 -2.620366e-03  0.003554         query_bullets_brand_matching
# 46  0.000000 -2.089753e-02  0.003084      query_decription_brand_matching
# 47  0.000000  9.236108e-03  0.007354              query_material_matching
# 2   0.000000 -1.193310e-02  0.007293      query_materialintitile_matching
# 3   0.000000 -6.080789e-05  0.003473      query_bullets_material_matching
# ...
